# %%
"""
RoLA (Real-time Online Lightweight Anomaly Detection) - With Ground Truth Evaluation
Author: Samuel Moses Orokpo
Date: 20th March, 2025

Features:
- Used LSTM-based anomaly detectors (LADs) for time series
- Implemented real-time dynamic thresholding
- Simplified Correlation-based anomaly confirmation
- Evaluated Precision, Recall, F-score, and Inference Time Statistics using `Anomaly_Label`
"""

import tensorflow as tf
import numpy as np
import pandas as pd
import time
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix


### Configurations

CONFIG = {
    "LOOKBACK": 10,  # LSTM input window size (10 to better understand pattern overtime)
    "HIDDEN_UNITS": 10,
    "LEARNING_RATE": 0.005,
    "EPOCHS": 10,  # Optimized for efficiency
    "BATCH_SIZE": 1,
    "SLIDING_WINDOW_SIZE": 1000,  # Used for adaptive thresholding
    "CORREL_THRESHOLD": 0.90,  # Pearson correlation threshold for anomaly confirmation
}


### LSTM-Based Lightweight Anomaly Detector (LAD)

class OnlineLSTMDetector:
    """ LSTM-based Anomaly Detector """

    def __init__(self, lookback=5, hidden_units=10, lr=0.005):
        self.lookback = lookback
        self.hidden_units = hidden_units
        self.lr = lr
        self.model = self._build_model()
        self.aare_history = []
        self.train_data = []

    def _build_model(self):
        """ Build LSTM Model """
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(self.lookback, 1)),
            tf.keras.layers.LSTM(self.hidden_units, activation='tanh'),
            tf.keras.layers.Dense(1)
        ])
        optimizer = tf.keras.optimizers.Adam(self.lr)
        model.compile(optimizer=optimizer, loss='mean_squared_error')
        return model

    def _compute_aare(self, y_true, y_pred):
        """ Compute Average Absolute Relative Error (AARE) """
        return np.abs(y_true - y_pred) / (np.abs(y_true) + 1e-9)

    def update_and_detect(self, new_data):
        """ Process new data, detect anomalies """
        self.train_data.append(new_data)
        anomaly_detected = False

        if len(self.train_data) >= self.lookback:
            X = np.array(self.train_data[-self.lookback:]).reshape(1, self.lookback, 1)
            prediction = self.model.predict(X, verbose=0)[0][0]
            aare_value = self._compute_aare(new_data, prediction)
            self.aare_history.append(aare_value)

            ### Dynamic thresholding using a rolling window
            if len(self.aare_history) > CONFIG["LOOKBACK"]:
                recent_errors = self.aare_history[-CONFIG["SLIDING_WINDOW_SIZE"]:]
                threshold = np.mean(recent_errors) + 3.5 * np.std(recent_errors)#(Strict to reduce FP)
                if aare_value > threshold:
                    anomaly_detected = True

        return anomaly_detected

### RoLA System

class RoLA:
    """ RoLA Multivariate Anomaly Detection """

    def __init__(self, num_variables):
        self.num_variables = num_variables
        self.lads = [OnlineLSTMDetector(lookback=CONFIG["LOOKBACK"]) for _ in range(num_variables)]
        self.data_history = [[] for _ in range(num_variables)]

    def process_data_point(self, data_point, index):
        anomalies = [self.lads[i].update_and_detect(data_point[i]) for i in range(self.num_variables)]

        ### Correlation-based confirmation
        confirmed_anomalies = anomalies.copy()
        if sum(anomalies) > 0:
            for i in range(self.num_variables):
                for j in range(self.num_variables):
                    if i != j:
                        corr = np.corrcoef(self.data_history[i][-100:], self.data_history[j][-100:])[0, 1]
                        if abs(corr) > CONFIG["CORREL_THRESHOLD"]:
                            confirmed_anomalies[i] = confirmed_anomalies[i] or anomalies[j]

        ### Logging detected anomalies
        if any(confirmed_anomalies):
            print(f"🔍Anomaly detected at index {index}: {confirmed_anomalies}")

        return confirmed_anomalies


### Evaluation Function

def evaluate_results(ground_truth, predictions, inference_times):
    """ Compute Precision, Recall, F1-score, and timing statistics """
    tp = sum((ground_truth == 1) & (predictions == 1))
    fp = sum((ground_truth == 0) & (predictions == 1))
    fn = sum((ground_truth == 1) & (predictions == 0))

    precision = precision_score(ground_truth, predictions, zero_division=0)
    recall = recall_score(ground_truth, predictions, zero_division=0)
    f1 = f1_score(ground_truth, predictions, zero_division=0)

    avg_time = np.mean(inference_times)
    std_time = np.std(inference_times)

    print(f"\n📝 Evaluation Metrics:")
    print(f"➡️ TP: {tp}, FP: {fp}, FN: {fn}")
    print(f"➡️ Precision: {precision:.3f}, Recall: {recall:.3f}, F1-score: {f1:.3f}")
    print(f"➡️ Avg Inference Time: {avg_time:.6f}s, Std Dev: {std_time:.6f}s")


### Main Execution

def main():
    print("\n➡️ Running RoLA Anomaly Detection...")

    # Loading the dataset
    df = pd.read_csv("Labeled_Dataset_with_Anomaly_Labels.csv")
    df["Timestamp"] = pd.to_datetime(df["Timestamp"])
    df.set_index("Timestamp", inplace=True)

    # Extracting anomaly labels
    ground_truth = df["Anomaly_Label"].values
    df.drop(columns=["Anomaly_Label"], inplace=True)  # Remove labels from input data

    # Selecting numeric data only
    data_array = df.values.astype(float)

    # Initializing RoLA system
    rola_system = RoLA(num_variables=data_array.shape[1])

    predictions = []
    inference_times = []

    # Processing each time step
    for i, row in enumerate(data_array):
        start_time = time.time()
        anomalies = rola_system.process_data_point(row, i)
        end_time = time.time()

        predictions.append(1 if any(anomalies) else 0)
        inference_times.append(end_time - start_time)

    # Evaluating performance
    evaluate_results(ground_truth, np.array(predictions), inference_times)

if __name__ == "__main__":
    main()
# Out:
# ➡️ Running RoLA Anomaly Detection...
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e6e364f5c60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e6e364f6840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:557: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2914: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# 🔍Anomaly detected at index 77: [False, True, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 388: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 389: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 602: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 603: [False, False, True, True, False, False, False, False, False]
# 🔍Anomaly detected at index 604: [False, True, False, True, False, True, False, False, False]
# 🔍Anomaly detected at index 605: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 606: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 607: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 608: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 609: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 610: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 611: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 694: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 695: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 696: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 697: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 698: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 699: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 700: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 701: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 702: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 703: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 704: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 705: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 706: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 707: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 708: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 709: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 710: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 711: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 712: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 713: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 714: [True, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 715: [True, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 717: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 725: [False, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 726: [False, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 727: [True, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 728: [True, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 729: [True, False, False, True, False, False, False, False, False]
# 🔍Anomaly detected at index 730: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 731: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 732: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 733: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 734: [True, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 735: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 736: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 737: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 738: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 739: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 740: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 741: [False, True, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 742: [False, True, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 743: [False, True, False, False, False, True, False, True, False]
# 🔍Anomaly detected at index 744: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 745: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 746: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 747: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 748: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 749: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 750: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 751: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 752: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 753: [False, True, False, False, False, True, False, False, True]
# 🔍Anomaly detected at index 754: [False, True, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 755: [False, True, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 756: [False, True, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 757: [False, True, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 758: [False, True, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 759: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 760: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 761: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 762: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2326: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2327: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2328: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2329: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2330: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2331: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2332: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2333: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2334: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2335: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2336: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2337: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2338: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2339: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2340: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2341: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2342: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2343: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2344: [False, False, True, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2345: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2346: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2348: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2349: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2350: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2352: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2353: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2354: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2355: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2357: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2359: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2362: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 2363: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2385: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2389: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2408: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2441: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2497: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2498: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2514: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2573: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2610: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2637: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2643: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2646: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2672: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2693: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2723: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2751: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2785: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 2786: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3134: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3135: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3136: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3137: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3138: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3139: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3140: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3141: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3142: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3143: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3144: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3145: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3146: [False, False, False, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3147: [False, False, True, False, False, True, False, False, False]
# 🔍Anomaly detected at index 3148: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3151: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3153: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3154: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3156: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3160: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3161: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3181: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3483: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3484: [False, True, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 3485: [False, True, False, True, True, False, False, False, False]
# 🔍Anomaly detected at index 3486: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3487: [False, True, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3488: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3489: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3490: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3491: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3492: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 3493: [False, True, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 4093: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4094: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4095: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4096: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4097: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4098: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4099: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4100: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4101: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4102: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4103: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4104: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4105: [False, False, False, False, False, False, False, True, True]
# 🔍Anomaly detected at index 4106: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4107: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4108: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4109: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4110: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4111: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4112: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4113: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4114: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4115: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4116: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4117: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4118: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4119: [False, False, False, False, False, False, False, False, True]
# 🔍Anomaly detected at index 4206: [False, False, True, False, False, False, False, False, False]
# 🔍Anomaly detected at index 4207: [False, True, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 4208: [False, False, False, False, True, False, True, False, False]
# 🔍Anomaly detected at index 4209: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 4210: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 4211: [False, False, False, False, True, False, False, False, False]
# 🔍Anomaly detected at index 4264: [False, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4265: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4266: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4267: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4268: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4269: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4270: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4271: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4272: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4273: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4274: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4275: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4276: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4277: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4278: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4281: [True, False, False, False, False, False, False, False, False]
# 🔍Anomaly detected at index 4282: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4283: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4284: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4285: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4286: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4287: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4288: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4289: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4290: [True, False, False, False, False, False, True, False, False]
# 🔍Anomaly detected at index 4291: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4292: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4293: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4294: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4295: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4296: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4297: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4298: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4299: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4300: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4301: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4302: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4303: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4304: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4305: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4306: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4307: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4308: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4309: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4310: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4311: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4312: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4313: [True, False, False, True, False, False, True, False, False]
# 🔍Anomaly detected at index 4314: [True, False, False, True, False, False, True, False, False]
#
# 📝 Evaluation Metrics:
# ➡️ TP: 71, FP: 168, FN: 38
# ➡️ Precision: 0.297, Recall: 0.651, F1-score: 0.408
# ➡️ Avg Inference Time: 0.619152s, Std Dev: 0.043271s
